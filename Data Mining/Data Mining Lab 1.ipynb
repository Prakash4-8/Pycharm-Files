# %%
# load dataset
# drop row and column which are not required
# drop missing values
# creat dummy variables
# tackle missing data
# convert the data into numpy
# devide the data into training and testing data

# %%
import sklearn
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
import numpy as np
import pandas as pd

# %%
init_data= pd.read_csv("C:/Users/bablu/Downloads/world-happiness-report-2019.csv")

# %%
init_data
# Out:
#              Country (region)  Ladder  SD of Ladder  Positive affect  \
# 0                     Finland       1             4             41.0
# 1                     Denmark       2            13             24.0
# 2                      Norway       3             8             16.0
# 3                     Iceland       4             9              3.0
# 4                 Netherlands       5             1             12.0
# ..                        ...     ...           ...              ...
# 151                    Rwanda     152            63             54.0
# 152                  Tanzania     153           122             78.0
# 153               Afghanistan     154            25            152.0
# 154  Central African Republic     155           117            132.0
# 155               South Sudan     156           140            127.0
#
#      Negative affect  Social support  Freedom  Corruption  Generosity  \
# ...

# %%
init_data2 = init_data.iloc[:,3:]

# %%
init_data3 = init_data2

# %%
init_data2
# Out:
#      Positive affect  Negative affect  Social support  Freedom  Corruption  \
# 0               41.0             10.0             2.0      5.0         4.0
# 1               24.0             26.0             4.0      6.0         3.0
# 2               16.0             29.0             3.0      3.0         8.0
# 3                3.0              3.0             1.0      7.0        45.0
# 4               12.0             25.0            15.0     19.0        12.0
# ..               ...              ...             ...      ...         ...
# 151             54.0            102.0           144.0     21.0         2.0
# 152             78.0             50.0           131.0     78.0        34.0
# 153            152.0            133.0           151.0    155.0       136.0
# 154            132.0            153.0           155.0    133.0       122.0
# 155            127.0            152.0           148.0    154.0        61.0
#
#      Generosity  Log of GDP\nper capita  Healthy life\nexpectancy
# ...

# %%
init_data2.dropna()
# Out:
#      Positive affect  Negative affect  Social support  Freedom  Corruption  \
# 0               41.0             10.0             2.0      5.0         4.0
# 1               24.0             26.0             4.0      6.0         3.0
# 2               16.0             29.0             3.0      3.0         8.0
# 3                3.0              3.0             1.0      7.0        45.0
# 4               12.0             25.0            15.0     19.0        12.0
# ..               ...              ...             ...      ...         ...
# 151             54.0            102.0           144.0     21.0         2.0
# 152             78.0             50.0           131.0     78.0        34.0
# 153            152.0            133.0           151.0    155.0       136.0
# 154            132.0            153.0           155.0    133.0       122.0
# 155            127.0            152.0           148.0    154.0        61.0
#
#      Generosity  Log of GDP\nper capita  Healthy life\nexpectancy
# ...

# %%
init_data2
# Out:
#      Positive affect  Negative affect  Social support  Freedom  Corruption  \
# 0               41.0             10.0             2.0      5.0         4.0
# 1               24.0             26.0             4.0      6.0         3.0
# 2               16.0             29.0             3.0      3.0         8.0
# 3                3.0              3.0             1.0      7.0        45.0
# 4               12.0             25.0            15.0     19.0        12.0
# ..               ...              ...             ...      ...         ...
# 151             54.0            102.0           144.0     21.0         2.0
# 152             78.0             50.0           131.0     78.0        34.0
# 153            152.0            133.0           151.0    155.0       136.0
# 154            132.0            153.0           155.0    133.0       122.0
# 155            127.0            152.0           148.0    154.0        61.0
#
#      Generosity  Log of GDP\nper capita  Healthy life\nexpectancy
# ...

# %%
init_data2.head(36)
# Out:
#     Positive affect  Negative affect  Social support  Freedom  Corruption  \
# 0              41.0             10.0             2.0      5.0         4.0
# 1              24.0             26.0             4.0      6.0         3.0
# 2              16.0             29.0             3.0      3.0         8.0
# 3               3.0              3.0             1.0      7.0        45.0
# 4              12.0             25.0            15.0     19.0        12.0
# 5              44.0             21.0            13.0     11.0         7.0
# 6              34.0              8.0            25.0     10.0         6.0
# 7              22.0             12.0             5.0      8.0         5.0
# 8              18.0             49.0            20.0      9.0        11.0
# 9              64.0             24.0            31.0     26.0        19.0
# 10             47.0             37.0             7.0     17.0        13.0
# 11              4.0             87.0            42.0     16.0        58.0
# ...

# %%
init_data4 = init_data3.fillna(init_data3.mean())

# %%
init_data3.mean()
# Out:
# Positive affect             78.0
# Negative affect             78.0
# Social support              78.0
# Freedom                     78.0
# Corruption                  74.5
# Generosity                  78.0
# Log of GDP\nper capita      76.5
# Healthy life\nexpectancy    75.5
# dtype: float64

# %%
init_data4.head(35)
# Out:
#     Positive affect  Negative affect  Social support  Freedom  Corruption  \
# 0              41.0             10.0             2.0      5.0         4.0
# 1              24.0             26.0             4.0      6.0         3.0
# 2              16.0             29.0             3.0      3.0         8.0
# 3               3.0              3.0             1.0      7.0        45.0
# 4              12.0             25.0            15.0     19.0        12.0
# 5              44.0             21.0            13.0     11.0         7.0
# 6              34.0              8.0            25.0     10.0         6.0
# 7              22.0             12.0             5.0      8.0         5.0
# 8              18.0             49.0            20.0      9.0        11.0
# 9              64.0             24.0            31.0     26.0        19.0
# 10             47.0             37.0             7.0     17.0        13.0
# 11              4.0             87.0            42.0     16.0        58.0
# ...

# %%
numpyArray = np.array(init_data)

# %%
numpyArray
# Out:
# array([['Finland', 1, 4, ..., 47.0, 22.0, 27.0],
#        ['Denmark', 2, 13, ..., 22.0, 14.0, 23.0],
#        ['Norway', 3, 8, ..., 11.0, 7.0, 12.0],
#        ...,
#        ['Afghanistan', 154, 25, ..., 137.0, 134.0, 139.0],
#        ['Central African Republic', 155, 117, ..., 113.0, 152.0, 150.0],
#        ['South Sudan', 156, 140, ..., 85.0, 140.0, 143.0]], dtype=object)

# %%
X = init_data4.iloc[:, :7]
y = init_data4.iloc[:,7:]
! pip install sklearn

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.05, random_state=0)
